# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

fig, ax = plt.subplots(figsize=(10,6))

# Audio branch
ax.add_patch(patches.Rectangle((0.2,0.7),0.3,0.15,edgecolor='black',facecolor='#a6cee3'))
ax.text(0.35,0.775,'Audio Input\n(Mel-Spectrogram)',ha='center',va='center')

ax.add_patch(patches.Rectangle((0.6,0.7),0.3,0.15,edgecolor='black',facecolor='#1f78b4'))
ax.text(0.75,0.775,'Audio Encoder\n(Spectrogram-ViT)',ha='center',va='center',color='white')

# Text branch
ax.add_patch(patches.Rectangle((0.2,0.45),0.3,0.15,edgecolor='black',facecolor='#b2df8a'))
ax.text(0.35,0.525,'Text Input\n(Transcript .txt)',ha='center',va='center')

ax.add_patch(patches.Rectangle((0.6,0.45),0.3,0.15,edgecolor='black',facecolor='#33a02c'))
ax.text(0.75,0.525,'Text Encoder\n(mBERT/XLM-R)',ha='center',va='center',color='white')

# Fusion & classifier
ax.add_patch(patches.Rectangle((0.45,0.2),0.4,0.15,edgecolor='black',facecolor='#fb9a99'))
ax.text(0.65,0.275,'Fusion [v_a; v_t]\n+ FFN Classifier',ha='center',va='center')

# Loss blocks
ax.add_patch(patches.Rectangle((0.05,0.35),0.25,0.08,edgecolor='black',facecolor='#fdbf6f'))
ax.text(0.175,0.39,'Sigmoid Matching\nLoss (Alignment)',ha='center',va='center')

ax.add_patch(patches.Rectangle((0.9,0.25),0.25,0.08,edgecolor='black',facecolor='#e31a1c'))
ax.text(1.025,0.29,'BCE Loss\n(AD vs HC)',ha='center',va='center',color='white')

# Arrows
ax.annotate('', xy=(0.6,0.775), xytext=(0.5,0.775), arrowprops=dict(arrowstyle='->'))
ax.annotate('', xy=(0.6,0.525), xytext=(0.5,0.525), arrowprops=dict(arrowstyle='->'))
ax.annotate('', xy=(0.65,0.35), xytext=(0.65,0.45), arrowprops=dict(arrowstyle='->'))
ax.annotate('', xy=(0.65,0.35), xytext=(0.65,0.7), arrowprops=dict(arrowstyle='->'))
ax.annotate('', xy=(0.85,0.275), xytext=(0.9,0.275), arrowprops=dict(arrowstyle='->'))
ax.annotate('', xy=(0.45,0.2), xytext=(0.2,0.39), arrowprops=dict(arrowstyle='->'))

ax.axis('off')
plt.show()
